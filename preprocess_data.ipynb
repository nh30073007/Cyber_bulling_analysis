# %%
# preprocess task....remove urls, convert lowercase, tokenize the text, remove stopwords, stemming, lemmatization

import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re



# DATASET 


df = pd.read_csv(r"C:\Users\nh013\Desktop\cyber bulling dataset\data.csv")

# FUNCTION FOR PREPROCESS.....


def preprocess_text(text):
    if isinstance(text, str):
        
        # REMOVE URLS
        text = re.sub(r"http\S+|www\S+|https\S+", "", text)

        
        # CONVERT TO LOWER CASE
        text = text.lower()

        
        # TOKENIZE THE TEXT
        tokens = word_tokenize(text)

        
        # REMOVE STOP WORDS
        stop_words = set(stopwords.words("english"))
        filtered_tokens = [token for token in tokens if token not in stop_words]

        
        # STEMMING
        stemmer = SnowballStemmer("english")
        stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]

        
        # LEMMATIZATION
        lemmatizer = WordNetLemmatizer()
        lemmatized_tokens = [lemmatizer.lemmatize(token) for token in stemmed_tokens]

        
        # JOIN THE TOKEN BACK INTO TEXT
        preprocessed_text = " ".join(lemmatized_tokens)
    
        return preprocessed_text
    else:
        return text

    
# SELECT TEXT COLUMN FOR PROCESS
text_columns = [
    "Email Address",
    "What do you consider as Cyber bullying?",
    "If Yes , What was the way you dealt with the same",
    "What do you think made you the victim of cyber bullying?",
    "What Platform according to you leads in cyber bullying",
    "What type of people are usually the bullies on the internet?",
    "What lead you to bully someone ? ( if yes )",
    "What kind of people are usually the victims of cyber-bullying?",
    "What are the causes of cyber bullying according to you",
    "Who are bullies usually?",
    "Youtube Roasting is a form of bullying. Do you agree ?",
    
]

for column in text_columns:
    df[column] = df[column].apply(preprocess_text)


print(df.head())
# Out:
#             Timestamp                 Email Address What's Your Age?  \
# 0  1/22/2022 11:39:31      armadhav2007 @ gmail.com          15 - 18
# 1  1/22/2022 11:40:39  nikhilkumar38674 @ gmail.com         Above 18
# 2  1/22/2022 11:41:15      guptasayyam7 @ gmail.com          15 - 18
# 3  1/22/2022 11:41:57      sonaissuhani @ gmail.com          15 - 18
# 4  1/22/2022 11:42:02        madmaxhu69 @ gmail.com          15 - 18
#
#              What do you consider as Cyber bullying?  \
# 0  hack / phish privat detail , spam , unlaw morp...
# 1  hack / phish privat detail , spam , unlaw morp...
# 2  spam , unlaw morph imag , messag call contain ...
# 3  mean/inappropri comment , prank call stranger ...
# 4  mean/inappropri comment , spam , unlaw morph i...
#
#   What Age group of people are most Vulnerable to Cyber bullying  \
# 0                                              19-30
# 1                                 equally vulnerable
# 2                                            15 - 18
# 3                                            15 - 18
# 4                                           Below 15
#
#   Have you ever been cyber bullied?  \
# 0                                No
# 1                                No
# 2                               Yes
# 3                               Yes
# 4                                No
#
#    If Yes , What was the way you dealt with the same  \
# 0                                                NaN
# 1                                                NaN
# 2                               block / report bulli
# 3  scare anyth , block / report bulli , file offi...
# 4  aaj mere paa bangla 🏢 hai , gadi hai 🚗 , bank-...
#
#   What do you think made you the victim of cyber bullying?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                idk
# 3                                            immatur
# 4  kanta 🪡 laga 🤧 ooi 🥴 maa 😫 ooi 🥴maa😫 ooi 🥴maa😩...
#
#   What Platform according to you leads in cyber bullying  \
# 0                                   whatsapp / email
# 1                                            discord
# 2                                            discord
# 3                                          instagram
# 4  hum💪🏻 tum mein😖 itn ched kareng 🙀👌🏻 ... ki con...
#
#   What type of people are usually the bullies on the internet?  \
# 0                                              money
# 1                                      comput friend
# 2                              anyon get cyber bulli
# 3                 peopl useless dont anyth good life
# 4                    one ai n't get attent irl onlin
#
#   Have You ever knowingly / Unknowingly bullied someone on the internet?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#   What lead you to bully someone ? ( if yes )  \
# 0                                         NaN
# 1                                privaci leak
# 2                                         NaN
# 3                                reveng bulli
# 4                              mozzer hu bhay
#
#   What kind of people are usually the victims of cyber-bullying?  \
# 0
# 1                       peopl distinct physic appear
# 2
# 3
# 4                            influenc / famous peopl
#
#   What are the causes of cyber bullying according to you  \
# 0                                          lack awar
# 1                                          lack awar
# 2                                          lack awar
# 3                                          lack awar
# 4                                             sadism
#
#   What has more impact on an individual , Cyber Bullying or Bullying in real life ?  \
# 0                                     Cyber Bullying
# 1                                       equal impact
# 2                                       equal impact
# 3                                     Cyber Bullying
# 4                              Bullying in real life
#
#   Who are bullies usually?  \
# 0
# 1
# 2
# 3                 stranger
# 4
#
#   Youtube Roasting is a form of bullying. Do you agree ?  \
# 0
# 1                                                yes
# 2
# 3                                                yes
# 4
#
#   Your opinion on the dank communities on  the internet , usually involved in bullying?
# 0                                                  -
# 1                                                no
# 2                     goverment should take a action
# 3  According to my opinion, not everyone likes ge...
# 4  Ye gajar 🥕 hai 😮 lagta hai 🤔 abhi khanka 🍗 hai...
